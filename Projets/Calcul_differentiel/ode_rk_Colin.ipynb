# %% [markdown]
# # TP Algorithme de Runge Kutta
#
# **Document à rendre au plus tard le 25 septembre à 18h00**
#
# Nom : Colin
#
# Prénom : Rémi
#
# ## Introduction
#
# Il est rappelé que les programmes doivent respecter les **bonnes pratiques de la programmation**. En particulier on vérifiera que les interfaces soient bien définies (paramètres en entrée, en sortie avec leurs types, les dimensions, ...). Dans le cas contraire on mettra des **points négatifs** pour un maximum de 4 points.
#
# On rappelle qu'un schéma de Runge Kutta à $s$ étage est défini par
# \begin{equation}\label{eq:irk}
# (S)\left\{\begin{array}{l}
# k_i=f(t_0+c_ih,x_0+h\sum_{j=1}^{s}a_{ij}k_j)\quad \textrm{pour}\;\;i=1,\ldots,s\\
# x_1=x_0+h\sum_{i=1}^{s}b_ik_i
# \end{array}\right.
# \end{equation}
# où les coefficients $c_i,a_{ij}$ et $b_i$ sont des constantes qui définissent précisément le schéma. On supposera toujours dans la suite que  $c_i=\sum_{j=1}^{s}a_{ij}$ pour $i=1,\ldots,s$.
#
# On représente en pratique ce schéma par le tableau de Butcher
# $$
# \begin{array}{c|ccc}
# c_1    & a_{11} & \ldots & a_{1s}\\
# \vdots & \vdots &        & \vdots\\
# c_s    & a_{s1} & \ldots & a_{ss}   \\ \hline
#        & b_1    & \ldots & b_s\\
# \end{array}$$
#
# Si la matrice des coefficient $A$ est triangulaire inférieure stricte alors le schéma est explicite, sinon il est implicite.
#
# On donne ci après les schémas les plus courant
#
# $$\begin{array}[t]{ccc}
# \begin{array}{c}
# \\ \\
# \begin{array}{c|c}
# 0 &   \\\hline
#  & 1
# \end{array}
# \end{array}
# & \begin{array}{c}
# \\
# \begin{array}{c|cc}
# 0 &  &\\
# 1/2 & 1/2 &\\ \hline
#  & 0 & 1
# \end{array}
# \end{array}
# & \begin{array}{c|ccc}
# 0 &  &  & \\
# 1/3 & 1/3 & & \\
# 2/3 & 0 & 2/3 & \\ \hline
#  & 1/4 & 0 & 3/4
# \end{array}\\
# \textrm{Euler} & \textrm{Runge} & \textrm{Heun}
# \end{array}$$
# $$\begin{array}[t]{cc}
# \begin{array}{c|cccc}
# 0 &  &  & &\\
# 1/2 & 1/2 & & &\\
# 1/2 & 0 & 1/2 & &\\
# 1 &   0 & 0   & 1 &\\ \hline
#  & 1/6 & 2/6 & 2/6 & 1/6
# \end{array}
# & \begin{array}{c|cc}
# 1/2-\sqrt{3}/6 & 1/4 & 1/4-\sqrt{3}/6\\
# 1/2+\sqrt{3}/6 & 1/4+\sqrt{3}/6 & 1/4\\ \hline
#  & 1/2 & 1/2
# \end{array}\\
# \textrm{La méthode Rk4} & \textrm{Gauss d'ordre 4}
# \end{array}$$

# %%
using LinearAlgebra
import Pkg; #Pkg.add("Printf")
using Printf

# %% [markdown]
# ## Les méthodes de Runge Kutta explicites

# %%
function euler(fun, tspan::Tuple{<:Real,<:Real}, x0::Vector{<:Real}, p::Vector{<:Real},
        N::Integer)::Tuple{Vector{Float64},Array{Float64,2}}
# Numerical integration via Euler scheme
# Input
# -----
# fun : second member of the ode
#       xpoint = fun(x,p,t)
#       xpoint : value of fun
#               array(n)
#       x      : state
#                array(n)
#       p      : vector of parameter
#       t      : time
#                real
# tspan : (t0, tf)
# x0 : initial condition
#       array(n)
# p  : vector of parameters
# N  : number of step
#      integer
# Output
# ------
# T   : vector of time
#       array(N+1)
# X   : X[i,:] is the approximation of x(t_i)
#       array(N+1,n)
# ----------------------------------------------
    n  = length(x0)             # dimension n
    T  = zeros(N+1)             # vecteur des temps
    X  = zeros(N+1,n)   # vecteur d'approximation de x(t)
    t0=tspan[1] # temps initial
    tf=tspan[2] # temps final
    X[1,:] = x0 
    h = (tf-t0)/N # pas
    
    for i in 1:N
        X[i+1,:] = X[i,:]+h*fun(X[i,:], p, T[i])
        T[i+1] = T[i]+h
    end

    return T,X  
end
# Out:
# euler (generic function with 1 method)

# %%
function runge(fun, tspan::Tuple{<:Real,<:Real}, x0::Vector{<:Real}, p::Vector{<:Real}, N::Integer)
# Numerical integration via the runge scheme
# the same as Euler
# ----------------------------------------------

    n  = length(x0)             # dimension n
    T  = zeros(N+1) #vecteur des temps
    X  = zeros(N+1,n) # vecteur d'approxiamtion de x(t)
    t0=tspan[1] # temps inital
    tf=tspan[2] #temps final
    h = (tf-t0)/N #pas
    X[1,:] = x0 

    for i in 1:N
        # On calcul k1 et k2 :
        k1 = fun(X[i,:],p,T[i])
        k2 = fun(X[i,:]+h*0.5*k1, p, T[i]+0.5*h)
        
        X[i+1,:] = X[i,:]+h*k2
        T[i+1] = T[i]+h
    end
    
    return T,X   
end
# Out:
# runge (generic function with 1 method)

# %%
function heun(fun, tspan::Tuple{<:Real,<:Real}, x0::Vector{<:Real}, p::Vector{<:Real}, N::Integer)
# Numerical integration via the Heun scheme
# the same as Euler
# ----------------------------------------------

    n  = length(x0)             # dimension n
    T  = zeros(N+1) #vecteur des temps
    X  = zeros(N+1,n) # vecteur d'approxiamtion
    t0=tspan[1] #temps initial
    tf=tspan[2] #temps final
    h = (tf-t0)/N #pas
    X[1,:] = x0

    for i in 1:N
        # On calcul k1, k2 et k3 :
        k1 = fun(X[i,:],p,T[i])
        k2 = fun(X[i,:]+h*(1/3)*k1, p, T[i]+(1/3)*h)
        k3 = fun(X[i,:]+h*(2/3)*k2,p, T[i]+(2/3)*h)
        
        X[i+1,:] = X[i,:]+h*(0.25*k1+0.75*k3)
        T[i+1] = T[i]+h
    end
    
    return T,X
end
# Out:
# heun (generic function with 1 method)

# %%
function rk4(fun, tspan::Tuple{<:Real,<:Real}, x0::Vector{<:Real}, p::Vector{<:Real}, N::Integer)
# Numerical integration via the RK4 scheme
# the same as Euler
# ----------------------------------------------

    n  = length(x0)             # dimension n
    T  = zeros(N+1) # vecteur des temps
    X  = zeros(N+1,n) # vecteur d'approximation
    t0=tspan[1] # temps initial
    tf=tspan[2] # temps final
    h = (tf-t0)/N # pas
    X[1,:] = x0

    for i in 1:N
        #On calcul k1, k2, k3 et k4 :
        k1 = fun(X[i,:], p, T[i])
        k2 = fun(X[i,:]+0.5*h*k1,p, T[i]+0.5*h)
        k3 = fun(X[i,:]+0.5*h*k2,p, T[i]+0.5*h)
        k4 = fun(X[i,:]+h*k3,p, T[i]+h)
        
        X[i+1,:] = X[i,:] + h*((1/6)*(k1+k4)+(2/6)*(k2+k3))
        T[i+1] = T[i] + h
    end
    
    return T,X
end
# Out:
# rk4 (generic function with 1 method)

# %% [markdown]
# ## Vérification des résultats pour N = 10

# %%
function vdp(x::Vector{<:Real},p::Vector{<:Real},t::Real)
# Van der Pol model
# second member of the IVP
# p : paramter vector
# t : time, variable not use here
#
    xpoint = similar(x)
    xpoint[1] = x[2]
    xpoint[2] = (1-x[1]^2)x[2] -x[1]
    return xpoint    
end

function affiche(T,X)
# Affiche les résulats : utile pour vérifier que l'on a les résultats attendus pour N=25
#
    N = length(T)-1
    for i in 1:N+1
        @printf("%20.15f %20.15f %20.15f\n", T[i],X[i,1],X[i,2])
    end
end

mu = 1
p = [mu]
tf = 6.6632868593231301896996820305
t0 = 0.0
tspan = (t0, tf)
x0 = [2.00861986087484313650940188,0]
N = 10

println("Euler")
T_Euler,X_Euler = euler(vdp, tspan, x0, p, N)
affiche(T_Euler,X_Euler)

println("Runge")
T_Runge,X_Runge = runge(vdp, tspan, x0, p, N)
affiche(T_Runge,X_Runge)

println("Heun")
T_Heun,X_Heun = heun(vdp, tspan, x0, p, N)
affiche(T_Heun,X_Heun)

println("RK4")
T_RK4,X_RK4 = rk4(vdp, tspan, x0, p, N)
affiche(T_RK4,X_RK4)
# Out:
# Euler
#    0.000000000000000    2.008619860874843    0.000000000000000
#    0.666328685932313    2.008619860874843   -1.338401032434280
#    1.332657371864626    1.116804859682459    0.029458487293659
#    1.998986057796939    1.136433894810396   -0.719553966980973
#    2.665314743729252    0.656974445534582   -1.337038672872153
#    3.331643429661565   -0.233932776401004   -2.281177517157184
#    3.997972115593877   -1.753946793786687   -3.562133341262534
#    4.664300801526190   -4.127498422185830    2.534846643721279
#    5.330629487458503   -2.438457389035097  -21.800755581293878
#    5.996958173390816  -16.964926207850183   51.673054627620850
#    6.663286859323128   17.466312380281039 -9812.202238480942469
# Runge
#    0.000000000000000    2.008619860874843    0.000000000000000
#    0.666328685932313    1.562712360278651    0.014729243646829
#    1.332657371864626    1.220894137875029   -0.531644111154892
#    1.998986057796939    0.653509832528317   -1.176382554058143
#    2.665314743729252   -0.425046060567530   -2.355437605902746
#    3.331643429661565   -2.328613474497056   -0.666821025659383
#    3.997972115593877   -1.601326538420963   -2.971936242570924
#    4.664300801526190   -2.194094633102912    2.142928059459987
#    5.330629487458503   -2.093551719985328    3.009462583470000
#    5.996958173390816   -1.883624518031323    3.696462462835581
#    6.663286859323128   -1.093338066861612    4.585206668061812
# Heun
#    0.000000000000000    2.008619860874843    0.000000000000000
#    0.666328685932313    1.863255533197435   -0.908266060321282
#    1.332657371864626    1.211064582800380   -0.970739550986403
#    1.998986057796939    0.340951280354486   -1.805621923056305
#    2.665314743729252   -1.343388532295027   -2.597289061805765
#    3.331643429661565   -1.553155419631253   -1.762194037001647
#    3.997972115593877   -1.761923667266568   -0.354168010449824
#    4.664300801526190   -1.696763283602981    0.676119846604791
#    5.330629487458503   -1.141093089779298    1.054354969329855
#    5.996958173390816   -0.188465573737061    1.992096663893662
#    6.663286859323128    1.593565087325986    2.154895921996050
# RK4
#    0.000000000000000    2.008619860874843    0.000000000000000
#    0.666328685932313    1.728289565064685   -0.434733098442855
#    1.332657371864626    1.281792525355265   -0.876907363239775
#    1.998986057796939    0.486631604430131   -1.622466234766065
#    2.665314743729252   -1.024410786018537   -2.556512804455776
#    3.331643429661565   -1.953005683961636   -0.209070573804532
#    3.997972115593877   -1.742817815413673    0.341277278614283
#    4.664300801526190   -1.337915627756918    0.814186086166159
#    5.330629487458503   -0.600769643339284    1.494502898570028
#    5.996958173390816    0.821446001908529    2.589914527582617
#    6.663286859323128    1.886292589030272    0.455334065676452

# %% [markdown]
# ## Graphiques de la figure 3 pour N = 25

# %%
using Plots

N=25
T_Euler,X_Euler = euler(vdp, tspan, x0, p, N)
T_Runge,X_Runge = runge(vdp, tspan, x0, p, N)
T_Heun,X_Heun = heun(vdp, tspan, x0, p, N)
T_RK4,X_RK4 = rk4(vdp, tspan, x0, p, N)

#Figure 3 (toutes les méthodes sur un même graph)
p1 = plot(X_Euler[:,1], X_Euler[:,2],title = "Sol de VDP pdp", label = "Euler", xlabel = "y1(t)", ylabel = "y2(t)")
plot!(X_Runge[:,1], X_Runge[:,2], label = "Runge")
plot!(X_Heun[:,1], X_Runge[:,2],label = "Heun") 
plot!(X_RK4[:,1], X_RK4[:,2], label = "RK4")

#Deuxieme graph
p2 = plot(T_Euler, X_Euler[:,1],title = "Sol de VDP comp 1", label = "Euler", xlabel = "t", ylabel = "y1(t)")
plot!(T_Runge, X_Runge[:,1], label = "Runge")
plot!(T_Heun,X_Heun[:,1], label = "Heun") 
plot!(T_RK4, X_RK4[:,1], label = "RK4")

#Troisième graph
p3 = plot(T_Euler, X_Euler[:,2],title = "Sol de VDP comp 2", label = "Euler", xlabel = "t", ylabel = "y2(t)")
plot!(T_Runge, X_Runge[:,2], label = "Runge")
plot!(T_Heun,X_Heun[:,2], label = "Heun") 
plot!(T_RK4, X_RK4[:,2], label = "RK4")

plot(p2, p3, p1, layout =(2,2), lw =2)

# %% [markdown]
# ## Graphique figure 1

# %%
N0 = [collect(120:60:1080); collect(1200:600:10800)]
err = zeros(4, length(N0))

for i in 1:length(N0)
    N = N0[i]
    err[1,i] = abs(euler(vdp, tspan, x0, p, N)[2][end,1] - x0[1])
    err[2,i] = abs(runge(vdp, tspan, x0, p, UInt64( N/2))[2][end,1] - x0[1])
    err[3,i] = abs(heun(vdp, tspan, x0, p,UInt64( N/3))[2][end,1] - x0[1])
    err[4,i] = abs(rk4(vdp, tspan, x0, p, UInt64(N/4))[2][end,1] - x0[1])
end

plot_ordre = plot(log10.(N0),log10.(err'), title = "Erreur globale en fonction du nombre d’évaluations", label = ["Euler" "Runge" "Heun" "RK4"], xlabel = "N0", lw =2)

# %% [markdown]
# ## Ordre pour les méthodes explicites
# On demande de réaliser la figure 1 uniquement pour la première variable

# %% [markdown]
# ## Runge Kutta implicite, schéma de Gauss
# ### Point fixe
# #### Code

# %%
function gauss_fp(fun, tspan::Tuple{<:Real,<:Real}, x0::Vector{<:Real}, p::Vector{<:Real},
        option)::Tuple{Vector{Float64},Array{Float64,2},Int,Array{Int,1}}
# Numerical integration with Gauss scheme and the fixed point algorithm
#
# Input parameters
# ----------------
# fun : second member of the ode
#       fun(x,p,t)
#       Input
#       x      : state
#                array(n)
#       p      : vector of parameters
#       t      : time
#                real
#       Output
#       xpoint : value of fun
#               array(n) 
# tspan = (t0,tf)
# x0    = initial point
#         array(n)
# option[1] = N = number of step
#                 Integer
# option[2] = maximum number of iterations for the fixed point
#             real
# option[3] = epsilon for the test of progress in the fixed point
#             real
#
# Output parameters
# -----------------
# T = vector of time
#     real(N+1)
# X = Matrix of solution
#     real(N+1,n)
# The line i of [T X] contains ti and x_i the approximation of x(t_i)
# ifail[i] = number of iteration for the fixed point on [t_i,t_{i+1}] if the fixed point converge
# ifail[i] = -1 if the fixed point don't converge on [t_i,t_{i+1}]: maximum number of iteration
# is attained in the fixed point
#            integer(N)
# nfun = number of evaluation of phi
#        integer
# ndfun = number of evaluation of the derivative of fun
#         integer
# ---------------------------------------------------------------------------------------------
#
# Initialisation
# --------------
# Coefficent of the Butcher's array

    N, nb_iteration_max, fpeps = option # réatribution des options dans des variables
    N = UInt64(N) 
    t0 = tspan[1] # temps initial
    tf = tspan[2] # temps final
    h = (tf-t0)/N # pas
    n  = length(x0)# dimension n  
    T  = zeros(N+1) # vecteur des temps 
    X  = zeros(N+1,n) # vecteur solution
    nfun = 0
    ifail = -1*ones(Int64,N) 
    X[1,:] = x0


    for i in 2:N+1
        k1 = fun(x0,p, t0+(0.5-(3^0.5/6))*h)
        k2 = fun(x0, p,t0+(0.5+(3^0.5/6))*h)
        normeprog = 1.0
        nb_iter = 0 #nombre d'itérations dans la boucle for
        nfun += 2
        while (normeprog>fpeps) & (nb_iter<nb_iteration_max)
            #On calcule les nouveaux k1 et k2 
            nouv_k1 = fun(x0+0.25*k1*h+(0.25-3^0.5/6)*k2*h,p, t0+(0.5-(3^0.5/6))*h)
            nouv_k2 = fun(x0+(0.25+3^0.5/6)*k1*h+0.25*k2*h,p,t0+(0.5+(3^0.5/6))*h)
            normeprog = norm([nouv_k1-k1 ; nouv_k2-k2])
            k1 = nouv_k1
            k2 = nouv_k2
            nb_iter += 1
            nfun += 2
        end

        if max(normeprog)<=fpeps #est vrai s'il y a convergence 
            ifail[i-1] = nb_iter
        end 

        t0 = t0 + h
        x0 = x0 + h*0.5*(k1+k2)
        X[i,:] = x0
        T[i] = t0 
    end

    return T,X,nfun,ifail
end
# Out:
# gauss_fp (generic function with 1 method)

# %% [markdown]
# #### Test dans le cas N = 10, nb_itmax = 15 et K_eps = 1.e-12

# %%
#Afficher les resultats
function affiche_gauss(T,X, nfun, ifail)
# Affiche les résulats : utile pour vérifier que l'on a les résultats attendus pour N=25
#
    for i in 1:N+1
        @printf("%20.15f %20.15f %20.15f\n", T[i],X[i,1],X[i,2])
    end
    println(nfun)
    println(ifail)
end

N = 10
mu = 1
p = [mu]
tf = 6.6632868593231301896996820305
t0 = 0.0
t0=tspan[1]
tf=tspan[2]
option = ([10, 15, 1.0e-06])
x0 = [2.00861986087484313650940188,0]

println("Gauss")
T_Gauss, X_Gauss, nfun, ifail = gauss_fp(vdp, tspan, x0, p, option)
affiche_gauss(T_Gauss,X_Gauss, nfun, ifail)
# Out:
# Gauss
#    0.000000000000000    2.008619860874843    0.000000000000000
#    0.666328685932313    1.748077038315635   -0.614452193067304
#    1.332657371864626    1.227167526678123   -0.975617349879985
#    1.998986057796939    0.345219364241332   -1.811976134160198
#    2.665314743729252   -1.241597780608768   -2.475124551330471
#    3.331643429661565   -2.013913987826556   -0.001168903518536
#    3.997972115593877   -1.753872199839338    0.612809197750127
#    4.664300801526190   -1.235039630038150    0.970480377872889
#    5.330629487458503   -0.359183505874150    1.797419504046429
#    5.996958173390816    1.222176651788524    2.495490845811688
#    6.663286859323128    2.014631389666057    0.015750010678871
# 296
# [-1, 13, 11, 15, -1, -1, 13, 11, 15, -1]

# %% [markdown]
# #### Graphique figure 3

# %%
#Même graphique avec toutes les autres méthodes 
using Plots

option = ([25, 15, 1.0e-06])
#Calcul de X et T pour le schéma de Gauss et N = 25
T_Gauss,X_Gauss = gauss_fp(vdp, tspan, x0, p, option)


#Figure 3 (toutes les méthodes sur un même graph)
p1 = plot(X_Euler[:,1], X_Euler[:,2],title = "Sol de VDP : pdp", label = "Euler", xlabel = "y1(t)", ylabel = "y2(t)")
plot!(X_Runge[:,1], X_Runge[:,2], label = "Runge")
plot!(X_Heun[:,1], X_Runge[:,2],label = "Heun") 
plot!(X_RK4[:,1], X_RK4[:,2], label = "RK4")
plot!(X_Gauss[:,1], X_Gauss[:,2], label = "Gauss")


#Deuxieme graph
p2= plot(T_Euler, X_Euler[:,1],title = "Sol de VDP comp 1", label = "Euler", xlabel = "t", ylabel = "y1(t)")
plot!(T_Runge, X_Runge[:,1], label = "Runge")
plot!(T_Heun,X_Heun[:,1], label = "Heun") 
plot!(T_RK4, X_RK4[:,1], label = "RK4")
plot!(T_Gauss, X_Gauss[:,1], label = "Gauss")

#Troisième graph
p3 = plot(T_Euler, X_Euler[:,2],title = "Sol de VDP comp 2", label = "Euler", xlabel = "t", ylabel = "y2(t)")
plot!(T_Runge, X_Runge[:,2], label = "Runge")
plot!(T_Heun,X_Heun[:,2], label = "Heun") 
plot!(T_RK4, X_RK4[:,2], label = "RK4")
plot!(T_Gauss, X_Gauss[:,2], label = "Gauss")

plot(p2, p3, p1, layout=(2,2), lw =2)

# %% [markdown]
# #### Graphique schéma de Gauss pour d'autres valeurs d'options

# %%
#1 er cas : nb itmax = 15 et K eps = 1.e-12 et N=25
option = ([25, 15, 1.0e-12])
T_Gauss,X_Gauss = gauss_fp(vdp, tspan, x0, p, option)

#2ème cas nb itmax = 2 et K eps = 1.e-12 et N = 25
option2 = ([25, 2, 1.0e-12])
T_Gauss2,X_Gauss2 = gauss_fp(vdp, tspan, x0, p, option2)

#3 eme cas nb itmax = 15 et K eps = 1.e-6 et N = 25
option3 = ([25, 15, 1.0e-06])
T_Gauss3,X_Gauss3 = gauss_fp(vdp, tspan, x0, p, option3)

# premier graph
p1 = plot(X_Gauss[:,1], X_Gauss[:,2],title = "Sol avec Gauss : pdp", label = "itmax = 15, K eps = 1.e-12", xlabel = "y1(t)", ylabel = "y2(t)")
plot!(X_Gauss2[:,1], X_Gauss2[:,2], label = "itmax = 2, K eps = 1.e-12", xlabel = "y1(t)", ylabel = "y2(t)")
plot!(X_Gauss3[:,1], X_Gauss3[:,2], label = "itmax = 15, K eps = 1.e-06", xlabel = "y1(t)", ylabel = "y2(t)")

# deuxième graph
p2 = plot(T_Gauss, X_Gauss[:,1], title ="Sol avec Gauss : comp 1", label = "itmax = 15, K eps = 1.e-12")
plot!(T_Gauss2, X_Gauss2[:,1], label = "itmax = 2, K eps = 1.e-12")
plot!(T_Gauss3, X_Gauss3[:,1], label = "itmax = 15, K eps = 1.e-06", xlabel = "y1(t)", ylabel = "y2(t)")

# troisième graph
p3 = plot(T_Gauss, X_Gauss[:,2], title = "Sol avec Gauss : comp 2", label = "itmax = 15, K eps = 1.e-12")
plot!(T_Gauss2, X_Gauss2[:,2], label = "itmax = 2, K eps = 1.e-12")
plot!(T_Gauss3, X_Gauss3[:,2], label = "itmax = 15, K eps = 1.e-06", xlabel = "y1(t)", ylabel = "y2(t)")

plot(p2, p3, p1, layout =(2,2))

# %% [markdown]
# #### Ordre

# %%
N0 = [collect(120:60:1080) ; collect(1200:600:10800)]/4
err = zeros(1, length(N0)) #vecteur des erreurs par la méthode de gauss
nfun2 = zeros(1,length(N0))

for i in 1:length(N0)
    N = N0[i]
    nfun2[:,i] .= gauss_fp(vdp, tspan, x0, p, ([N, 15, 1.e-6]))[3]
    err[1,i] = abs(gauss_fp(vdp, tspan, x0, p, ([N, 15, 1.e-6]))[2][end,1] - x0[1])
end

plot_ordre_gauss = plot(plot_ordre, log10.(nfun2'),log10.(err'), label = "Gauss", title ="Erreur globale en fonction du nombre d'évaluations", xlabel = "N0", lw =2)

# %% [markdown]
# ### Newton
# #### Code

# %%
function gauss_newton(fun, dfun, tspan::Tuple{<:Real,<:Real}, x0::Vector{<:Real}, p::Vector{<:Real},
        option)::Tuple{Vector{Float64},Array{Float64,2},Int,Int,Array{Int,1}}
# Numerical integration with Gauss scheme and the Newton algorithm
#
# Input parameters
# ----------------
# fun : second member of the ode
#       fun(x,p,t)
#       Input
#       x      : state
#                array(n)
#       p      : vector of parameters
#       t      : time
#                real
#       Output
#       xpoint : value of fun
#               array(n) 
# tspan = (t0,tf)
# x0    = initial point
#         array(n)
# option[1] = N = number of step
#                 Integer
# option[2] = maximum number of iterations for the Newton algorithm
#             real
# option[3] = epsilon for the test of progress in the Newton algorithm
#             real
#
# Output parameters
# -----------------
# T = vector of time
#     real(N+1)
# X = Matrix of solution
#     real(N+1,n)
# The line i of [T X] contains ti and x_i the approximation of x(t_i)
# ifail[i] = number of iteration for the fixed point on [t_i,t_{i+1}] if the fixed point converge
# ifail[i] = -1 if the fixed point don't converge on [t_i,t_{i+1}]: maximum number of iteration
# is attained in the fixed point
#            integer(N)
# nfun = number of evaluation of phi
#        integer
# ndfun = number of evaluation of the derivative of fun
#         integer
# ndfun = number of evaluation of the derivative of fun
#         integer
# ---------------------------------------------------------------------------------------------
    N, nb_iteration_max, fpeps = option # réatribution des options dans des variables
    N = UInt64(N)
    t0 = tspan[1] # temps initial
    tf = tspan[2] # temps final
    h = (tf-t0)/N # pas 
    n  = length(x0)# dimension n  
    T  = zeros(N+1) # vecteur des temps
    X  = zeros(N+1,n) # vecteur solution
    nfun = 0
    ifail = -1*ones(Int64,N)
    X[1,:] = x0
    ndfun = 0
    jacobi = zeros(4,4) #jacobienne de la fonction donnée


    for i in 2:N+1
        k1 = fun(x0,p, t0+(0.5-(3^0.5/6))*h)
        k2 = fun(x0, p,t0+(0.5+(3^0.5/6))*h)
        normeprog = 1.0
        nb_iter = 0 #nombre d'itération dans la boucle for
        nfun += 2
        while (normeprog>fpeps) & (nb_iter<nb_iteration_max)
            # Algorithme de Newton pour trouver k1 et k2
            jacobi[1:2,1:2] = h*0.25*dfun(x0+0.25*k1*h+(0.25-3^0.5/6)*k2*h,p, t0+(0.5-(3^0.5/6))*h)
            jacobi[1:2,3:4] = (1-2*3^0.5/3)*jacobi[1:2,1:2]
            jacobi[3:4,1:2] = h*(0.25+3^0.5/6)*dfun(x0+h*((1/4+3^0.5/6)*k1+0.25*k2),p, t0+(0.5+(3^0.5/6))*h)
            jacobi[3:4,3:4] = 1/(1+2*3^0.5/3)*jacobi[3:4,1:2]
            jacobi = Matrix(I, 4, 4) - jacobi 

            res = (jacobi)\[k1 .*ones(2)-fun(x0+h*(0.25*k1+(0.25-3^0.5/6)*k2), p,t0+(0.5-(3^0.5/6))*h); 
            k2 .* ones(2)-fun(x0+h*((0.25+3^0.5/6)*k1+0.25*k2), p,t0+(0.5+(3^0.5/6))*h)]
            k1 = k1 - res[1:2]
            k2 = k2 - res[3:4]
            normeprog = norm(res)

            ndfun+=2
            nfun += 2
            nb_iter += 1
        end

        if max(normeprog)<=fpeps #est vrai s'il y a convergence 
            ifail[i-1] = nb_iter
        end 

        t0 = t0 + h
        x0 = x0 + h*0.5*(k1+k2)
        X[i,:] = x0
        T[i] = t0 
    end


    return T,X,nfun,ndfun,ifail
end
# Out:
# gauss_newton (generic function with 1 method)

# %% [markdown]
# #### Test dans le cas N = 10, nb_itmax = 15 et K_eps = 1.e-12

# %%
function dvdp(x::Vector{<:Real},p::Vector{<:Real},t::Real)::Matrix{<:Real}
# Van der Pol model
# derivative of the second member of the IVP
# x : state
#     real(n)
# p : paramter vector
# t : time, variable not use here
#     real
# Output
# Xpoint::Jacobian matrix{<:Real},
#       real(n,n)
# --------------------------------------
    n = length(x)
    Jac = ones(n,n)
    Jac[1,1] = 0
    Jac[2,1] = -2*x[1]*x[2] -1
    Jac[1,2] = 1
    Jac[2,2] = (1-x[1]^2)
    
    return Jac
end
# Out:
# dvdp (generic function with 1 method)

# %%
#Afficher les resultats
function affiche_gauss_newton(T,X, nfun, ndfun, ifail)
# Affiche les résulats : utile pour vérifier que l'on a les résultats attendus pour N=25
#
    for i in 1:N+1
        @printf("%20.15f %20.15f %20.15f\n", T[i],X[i,1],X[i,2])
    end
    println("nfun : ", nfun)
    println("ndfun : ", ndfun)
    println(ifail)
end

N = 10
mu = 1
p = [mu]
tf = 6.6632868593231301896996820305
t0 = 0.0
tspan = (t0, tf)
option = ([10, 15, 1.0e-6])
x0 = [2.00861986087484313650940188,0]

println("Gauss")
T_Gauss_Newton, X_Gauss_Newton, nfun, ndfun, ifail = gauss_newton(vdp, dvdp, tspan, x0, p,option)
affiche_gauss_newton(T_Gauss_Newton,X_Gauss_Newton, nfun, ndfun,  ifail)
# Out:
# Gauss
#    0.000000000000000    2.008619860874843    0.000000000000000
#    0.666328685932313    1.748103353412420   -0.614524376585803
#    1.332657371864626    1.227167371665737   -0.975642346688062
#    1.998986057796939    0.345201034491682   -1.812011679746201
#    2.665314743729252   -1.241634876414838   -2.475102844185241
#    3.331643429661565   -2.013908638346081   -0.001153761617750
#    3.997972115593877   -1.753891509975080    0.612895411728274
#    4.664300801526190   -1.235024728110440    0.970518388811259
#    5.330629487458503   -0.359136669330347    1.797486858502427
#    5.996958173390816    1.222255698893968    2.495430848815410
#    6.663286859323128    2.014631461651370    0.015689664812240
# nfun : 96
# ndfun : 76
# [4, 3, 3, 4, 5, 4, 3, 3, 4, 5]

# %% [markdown]
# #### Graphique figure 3

# %%
#Même graphique avec toutes les autres méthodes 
using Plots

option = ([25, 15, 1.0e-06])
#Calcul de X et T pour le schéma de Gauss et N = 25
T_Gauss_Newton, X_Gauss_Newton, nfun, ndfun, ifail = gauss_newton(vdp, dvdp, tspan, x0, p,option)

#Figure 3 (toutes les méthodes sur un même graph)
p1 = plot(X_Gauss_Newton[:,1], X_Gauss_Newton[:,2], title = "Plan de phase", label = "Gauss Newton")

#Deuxieme graph
p2 = plot(T_Gauss_Newton, X_Gauss_Newton[:,1],title = "Composante 1", label = "Gauss Newton")

#Troisième graph
p3 = plot(T_Gauss_Newton, X_Gauss_Newton[:,2], title = "Composante 2", label = "Gauss Newton")

plot(p2, p3, p1, layout =(2,2), lw =2)

# %% [markdown]
# #### Graphique schéma de Gauss avec algo de Newton pour d'autres valeurs d'options

# %%
#1 er cas : nb itmax = 15 et K eps = 1.e-12 et N=25
option = ([25, 15, 1.0e-12])
T_Gauss_Newton, X_Gauss_Newton, nfun, ndfun, ifail = gauss_newton(vdp, dvdp, tspan, x0, p,option)


#2ème cas nb itmax = 2 et K eps = 1.e-12 et N = 25
option2 = ([25, 2, 1.0e-12])
T_Gauss_Newton2, X_Gauss_Newton2, nfun, ndfun, ifail = gauss_newton(vdp, dvdp, tspan, x0, p,option)


#3 eme cas nb itmax = 15 et K eps = 1.e-6 et N = 25
option3 = ([25, 15, 1.0e-06])
T_Gauss_Newton3, X_Gauss_Newton3, nfun, ndfun, ifail = gauss_newton(vdp, dvdp, tspan, x0, p,option)


p1 = plot(X_Gauss_Newton[:,1], X_Gauss_Newton[:,2], title = "Plan de phase", label = "itmax = 15, K eps = 1.e-12", xlabel = "y1(t)", ylabel = "y2(t)")
plot!(X_Gauss_Newton2[:,1], X_Gauss_Newton2[:,2], label = "itmax = 2, K eps = 1.e-12", xlabel = "y1(t)", ylabel = "y2(t)")
plot!(X_Gauss_Newton3[:,1], X_Gauss_Newton3[:,2], label = "itmax = 15, K eps = 1.e-06", xlabel = "y1(t)", ylabel = "y2(t)")



p2 = plot(T_Gauss_Newton, X_Gauss_Newton[:,1], title = "Composante 1", label = "itmax = 15, K eps = 1.e-12")
plot!(T_Gauss_Newton2, X_Gauss_Newton2[:,1], label = "itmax = 2, K eps = 1.e-12")
plot!(T_Gauss_Newton3, X_Gauss_Newton3[:,1], label = "itmax = 15, K eps = 1.e-06", xlabel = "y1(t)", ylabel = "y2(t)")


p3 = plot(T_Gauss_Newton, X_Gauss_Newton[:,2], title = "Composante 2", label = "itmax = 15, K eps = 1.e-12")
plot!(T_Gauss_Newton2, X_Gauss_Newton2[:,2], label = "itmax = 2, K eps = 1.e-12")
plot!(T_Gauss_Newton3, X_Gauss_Newton3[:,2], label = "itmax = 15, K eps = 1.e-06", xlabel = "y1(t)", ylabel = "y2(t)")

plot(p2, p3, p1)

# %% [markdown]
# #### Ordre

# %%
N0 = [collect(120:60:1080) ; collect(1200:600:10800)]/4
err = zeros(1, length(N0)) # vecteur des erreurs par Gauss-Newton
nfun2 = zeros(1, length(N0))

for i in 1:length(N0)
    N = N0[i]
    nfun2[:,i] .= gauss_newton(vdp,dvdp, tspan, x0, p, ([N, 15, 1.e-6]))[3]
    err[1,i] = abs(gauss_fp(vdp, tspan, x0, p, ([N, 15, 1.e-6]))[2][end,1] - x0[1])
end

plot(plot_ordre_gauss,log10.(nfun2'),log10.(err'), label = "Gauss Newton", xlabel = "N0", lw =2, title = "Erreur globale en fonction du nombre d'évaluations")

# %% [markdown]
# ### Interprétation/remarque :
# On remarque que pour Gauss et pour Gauss-Newton, on a à quelque chose près les mêmes valeurs de solutions mais des erreurs globales différentes.
# Cette différence est dûe au nombre d'appel de la fonction fun dans les différentes méthodes car dans la méthode de Gauss-Newton, on appel moins de fois fun. De plus, dans la méthode de gauss-Newton, les ki sont des points fixes de fun. Ces raisons entrainent alors une augmentation de l'erreur globale pour la méthode de Gauss par rapport à celle de Gauss-Newton.
